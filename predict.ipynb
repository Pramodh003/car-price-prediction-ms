# %%
import pandas as pd
data = pd.read_csv('CarPrice.csv')

# %%
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration  \
# 0       1          3        alfa-romero giulia      gas        std
# 1       2          3       alfa-romero stelvio      gas        std
# 2       3          1  alfa-romero Quadrifoglio      gas        std
# 3       4          2               audi 100 ls      gas        std
# 4       5          2                audi 100ls      gas        std
#
#    doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0           2  convertible        rwd          front       88.6  ...
# 1           2  convertible        rwd          front       88.6  ...
# 2           2    hatchback        rwd          front       94.5  ...
# 3           4        sedan        fwd          front       99.8  ...
# 4           4        sedan        4wd          front       99.4  ...
#
#    enginesize  fuelsystem  boreratio  stroke compressionratio  horsepower  \
# ...

# %%
data["CarName"].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
print(data["fueltype"].unique())
print(data["aspiration"].unique())
print(data["carbody"].unique())
print(data["drivewheel"].unique())	
print(data["enginelocation"].unique())
print(data["enginetype"].unique())
print(data["fuelsystem"].unique())
# Out:
# ['gas' 'diesel']
# ['std' 'turbo']
# ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# ['rwd' 'fwd' '4wd']
# ['front' 'rear']
# ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']
# ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder() 
  
string_data = ["CarName","fueltype","aspiration","carbody","drivewheel","enginelocation","enginetype","fuelsystem"]
# Encode labels in column 'species'. 
for i in string_data:
    data[i] = label_encoder.fit_transform(data[i])
    data.to_csv("processed_data.csv", index=False)

# %%
data.head()
# Out:
#    car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0       1          3        2         1           0           2        0
# 1       2          3        3         1           0           2        0
# 2       3          1        1         1           0           2        2
# 3       4          2        4         1           0           4        3
# 4       5          2        5         1           0           4        3
#
#    drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0           2               0       88.6  ...         130           5
# 1           2               0       88.6  ...         130           5
# 2           2               0       94.5  ...         152           5
# 3           1               0       99.8  ...         109           5
# 4           0               0       99.4  ...         136           5
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
# !pip install xgboost
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 24.1.2 is available.
# You should consider upgrading via the 'd:\fastapi-carprice\venv\scripts\python.exe -m pip install --upgrade pip' command.

# %%
# check xgboost version
import xgboost
from xgboost import XGBRegressor

# %%
model = XGBRegressor(n_estimators=1000, max_depth=7, eta=0.1, subsample=0.7, colsample_bytree=0.8)

# %%
X = data.drop(["price"],axis=1)
y = data["price"]

# %%
X.head()
# Out:
#    car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0       1          3        2         1           0           2        0
# 1       2          3        3         1           0           2        0
# 2       3          1        1         1           0           2        2
# 3       4          2        4         1           0           4        3
# 4       5          2        5         1           0           4        3
#
#    drivewheel  enginelocation  wheelbase  ...  cylindernumber  enginesize  \
# 0           2               0       88.6  ...               4         130
# 1           2               0       88.6  ...               4         130
# 2           2               0       94.5  ...               6         152
# 3           1               0       99.8  ...               4         109
# 4           0               0       99.4  ...               5         136
#
#    fuelsystem  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# ...

# %%
y.head()
# Out:
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# Name: price, dtype: float64

# %%
data.describe()
# Out:
#            car_ID   symboling     CarName    fueltype  aspiration  doornumber  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   77.209756    0.902439    0.180488    3.121951
# std     59.322565    1.245307   41.014583    0.297446    0.385535    0.994966
# min      1.000000   -2.000000    0.000000    0.000000    0.000000    2.000000
# 25%     52.000000    0.000000   44.000000    1.000000    0.000000    2.000000
# 50%    103.000000    1.000000   80.000000    1.000000    0.000000    4.000000
# 75%    154.000000    2.000000  115.000000    1.000000    0.000000    4.000000
# max    205.000000    3.000000  146.000000    1.000000    1.000000    4.000000
#
#           carbody  drivewheel  enginelocation   wheelbase  ...  enginesize  \
# count  205.000000  205.000000      205.000000  205.000000  ...  205.000000
# mean     2.614634    1.326829        0.014634   98.756585  ...  126.907317
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    int32
#  3   fueltype          205 non-null    int32
#  4   aspiration        205 non-null    int32
#  5   doornumber        205 non-null    int64
#  6   carbody           205 non-null    int32
#  7   drivewheel        205 non-null    int32
#  8   enginelocation    205 non-null    int32
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carh8             205 non-null    float64
#  13  curbw8            205 non-null    int64
#  14  enginetype        205 non-null    int32
#  15  cylindernumber    205 non-null    int64
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,y,random_state=10, test_size=30)

# %%
model.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eta=0.1, eval_metric=None,
#              feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=7,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_predict = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(Y_test,y_predict))
import numpy as np
# Out:
# 0.8963148011489788

# %%
import pickle

# %%
pickle.dump(model,open('model.pkl','wb'))

# %%
model_1 = pickle.load(open('model.pkl','rb'))

# %%
input_data = np.array([3, 2,0,1, 0, 2, 0, 2, 0, 88.6, 168.8, 64.1, 48.8, 2548, 0, 4, 130, 5, 3.47, 2.68, 9.0, 111, 5000, 21, 27]).reshape(1, -1)

# %%
predicted_price = model_1.predict(input_data)

# %%
print(predicted_price)
# Out:
# [13568.377]

# %%
string_data = ["CarName","fueltype","aspiration","carbody","drivewheel","enginelocation","enginetype","fuelsystem"]

# %%
data_dict  = {
    "symboling": 3,
    "CarName": "alfa-romero giulia",
    "fueltype": "gas",
    "aspiration": "std",
    "doornumber": 2,
    "carbody": "convertible",
    "drivewheel": "rwd",
    "enginelocation": "front",
    "wheelbase": 88.6,
    "carlength": 168.8,
    "carwidth": 64.1,
    "carheight": 48.8,
    "curbweight": 2548,
    "enginetype": "dohc",
    "cylindernumber": 4,
    "enginesize": 130,
    "fuelsystem": "mpfi",
    "boreratio": 3.47,
    "stroke": 2.68,
    "compressionratio": 9,
    "horsepower": 111,
    "peakrpm": 5000,
    "citympg": 21,
    "highwaympg": 27
}

# %%
categorical_features = ["CarName", "fueltype", "aspiration", "carbody", "drivewheel", "enginelocation", "enginetype", "fuelsystem"]
numerical_features = ["symboling", "doornumber", "wheelbase", "carlength", "carwidth", "carheight", "curbweight", "cylindernumber", "enginesize", "boreratio", "stroke", "compressionratio", "horsepower", "peakrpm", "citympg", "highwaympg"]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
encoded_feature = []

for feature in categorical_features:
    encoded = label_encoder.fit_transform([data_dict[feature]])
    encoded_feature.append(encoded[0])
    

all_features = encoded_feature + [data_dict[feature] for feature in numerical_features] + [0]

features = np.array(all_features).reshape(1, -1)

print(features)
# Out:
# [[0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#   0.000e+00 3.000e+00 2.000e+00 8.860e+01 1.688e+02 6.410e+01 4.880e+01
#   2.548e+03 4.000e+00 1.300e+02 3.470e+00 2.680e+00 9.000e+00 1.110e+02
#   5.000e+03 2.100e+01 2.700e+01 0.000e+00]]

# %%
predicted_price = model_1.predict(features)

# %%
print(predicted_price)
# Out:
# [12789.5205]

# %%
data.head()
# Out:
#    car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0       1          3        2         1           0           2        0
# 1       2          3        3         1           0           2        0
# 2       3          1        1         1           0           2        2
# 3       4          2        4         1           0           4        3
# 4       5          2        5         1           0           4        3
#
#    drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0           2               0       88.6  ...         130           5
# 1           2               0       88.6  ...         130           5
# 2           2               0       94.5  ...         152           5
# 3           1               0       99.8  ...         109           5
# 4           0               0       99.4  ...         136           5
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
data_dict = data.dict()
categorical_features = ["CarName", "fueltype", "aspiration", "carbody", "drivewheel", "enginelocation", "enginetype", "fuelsystem"]
numerical_features = ["symboling", "doornumber", "wheelbase", "carlength", "carwidth", "carheight", "curbweight", "cylindernumber", "enginesize", "boreratio", "stroke", "compressionratio", "horsepower", "peakrpm", "citympg", "highwaympg"]
encoded_feature = []
for feature in categorical_features:
    encoded = label_encoder.fit_transform([data_dict[feature]])
    encoded_feature.append(encoded[0])
    all_features = encoded_feature + [data_dict[feature] for feature in numerical_features] + [0]
    features = np.array(all_features).reshape(1, -1)
    predicted_price = model_1.predict(features)
    print(predicted_price)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 9
#       7 all_features = encoded_feature + [data_dict[feature] for feature in numerical_features] + [0]
#       8 features = np.array(all_features).reshape(1, -1)
# ----> 9 predicted_price = model_1.predict(features)
#      10 print(predicted_price)
#
# File d:\Fastapi-carprice\venv\lib\site-packages\xgboost\sklearn.py:1168, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1166 if self._can_use_inplace_predict():
#    1167     try:
# -> 1168         predts = self.get_booster().inplace_predict(
#    1169             data=X,
#    1170             iteration_range=iteration_range,
#    1171             predict_type="margin" if output_margin else "value",
#    1172             missing=self.missing,
#    1173             base_margin=base_margin,
# ...
